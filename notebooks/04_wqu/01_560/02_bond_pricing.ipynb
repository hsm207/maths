# %%
# %load_ext nb_black

# %%
import numpy_financial as npf

# %% [markdown]
# # Annual Interest Rate

# %% [markdown]
# # Annual Discount Factor

# %% [markdown]
# # Pricing An Annual Bond

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# the current discount rate to value the cash flows e.g. YTM
r = 5.3 / 100
# number of years to maturity
n = 10
fv = 1000
pmt = fv * 6.5 / 100
npf.pv(rate=r, nper=n, pmt=pmt, fv=fv)
# Out:
# -1091.3255724603764
